# %%
import pandas as pd

# %%
source_info = pd.read_csv('../data/SourceInfo.csv')
caa_c0=pd.read_csv("../data/caa_nrc_cluster_0.csv")
caa_c1=pd.read_csv("../data/caa_nrc_cluster_1.csv")
caa_c2=pd.read_csv("../data/caa_nrc_cluster_2.csv")
covid_c0=pd.read_csv("../data/covid_cluster_0.csv")
covid_c1=pd.read_csv("../data/covid_cluster_1.csv")
covid_c2=pd.read_csv("../data/covid_cluster_2.csv")
original_parsed_data = pd.read_csv("../data/parsed_cleaned.csv")
strong_words_data = pd.read_csv("../data/StrongWordsAnalysis.csv")

# %%
articles_data = pd.DataFrame(columns=["Source","Title","Cleaned Text","Source Reliability","Strong Words Score","Neutrality Score"])
# Out:
# Empty DataFrame
# Columns: [Source, Title, Cleaned Text, Source Reliability, Strong Words Score, Neutrality Score]
# Index: []

# %%
source_info
# Out:
#                 Source  Wikipedia  Year  Twitter  Verified Popularity  \
# 0              DD News          1  2003        1         1       High
# 1     Deccan Chronicle          1  1938        1         1        Low
# 2            FirstPost          1  2017        1         1        Low
# 3      Hindustan Times          1  1924        1         1       High
# 4          Independent          1  1986        1         1     Medium
# 5          India Today          1  2003        1         1       High
# 6       Indian Express          1  1932        1         1     Medium
# 7    Janta ka Reporter          0  2015        1         1        Low
# 8      National Herald          1  2017        1         1        Low
# 9                 NDTV          1  1988        1         1     Medium
# 10        News Laundry          0  2012        1         1        Low
# 11              News18          1  2005        1         1       High
# 12             OpIndia          1  2014        1         1     Medium
# 13           Organizer          1  1947        1         0        Low
# 14             Outlook          1  1995        1         1        Low
# 15      Rajya Sabha TV          1  2011        1         1        Low
# 16         Republic TV          1  2016        1         1       High
# 17             Reuters          1  1851        1         1       High
# 18              Scroll          1  2014        1         1        Low
# 19            Swarajya          1  2014        1         1        Low
# 20           The Hindu          1  1878        1         1     Medium
# 21           The Print          1  2017        1         1     Medium
# 22           The Quint          1  2015        1         1        Low
# 23       The Statesman          1  1875        1         1        Low
# 24       The Telegraph          1  1982        1         1     Medium
# 25         The Tribune          0  1881        1         1        Low
# 26            The Wire          1  2015        1         1        Low
# 27           Times Now          1  2006        1         1       High
# 28  The Times of India          1  1838        1         1       High
# 29            Zee News          1  1999        1         1       High
#
#     History  Controversy  SourceScore
# 0         1            0     0.422819
# 1         0            0     0.325503
# 2         0            0     0.060403
# 3         1            1     0.711409
# 4         1            0     0.355705
# 5         1            0     0.422819
# 6         1            0     0.536913
# 7         0            0     0.000000
# 8         1            1     0.151007
# 9         1            1     0.372483
# 10        0            0     0.010067
# 11        1            1     0.439597
# 12        1            0     0.261745
# 13        1            0     0.345638
# 14        1            0     0.201342
# 15        0            0     0.080537
# 16        1            1     0.402685
# 17        1            1     0.956376
# 18        1            0     0.137584
# 19        1            1     0.161074
# 20        1            1     0.741611
# 21        1            0     0.251678
# 22        1            0     0.134228
# 23        1            0     0.604027
# 24        1            0     0.369128
# 25        0            0     0.449664
# 26        1            1     0.157718
# 27        0            1     0.369128
# 28        1            1     1.000000
# 29        0            1     0.392617

# %%
articles_copy = caa_c0
articles_copy = articles_copy.append([caa_c1,caa_c2,covid_c0,covid_c1,covid_c2])
len(articles_copy)
# Out:
# 1781

# %%
articles = []
for i in articles_copy.index:
    if articles_copy['Text'].iloc[i] in list(original_parsed_data['Cleaned_text']):
        source=original_parsed_data['Source'].iloc[i]
        title=original_parsed_data['Title'].iloc[i]
        text=original_parsed_data['Cleaned_text'].iloc[i]
        source_reliability=source_info.loc[source_info['Source']==source]['SourceScore']
        strong_words_score = strong_words_data.loc[strong_words_data['Cleaned_text']==text,'strongP'].iloc[1]
        neutrality_score=articles_copy['neutrality'].iloc[i]
        articles.append([source,title,text,source_reliability,strong_words_score,neutrality_score])
print(len(articles))

print(articles[5])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-61-41341a7816b0> in <module>
#       6         text=original_parsed_data['Cleaned_text'].iloc[i]
#       7         source_reliability=source_info.loc[source_info['Source']==source,'SourceScore']
# ----> 8         strong_words_score = strong_words_data.loc[strong_words_data['Cleaned_text']==text,'strongP'].iloc[1]
#       9         neutrality_score=articles_copy['neutrality'].iloc[i]
#      10         articles.append([source,title,text,source_reliability,strong_words_score,neutrality_score])
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1422
#    1423             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1424             return self._getitem_axis(maybe_callable, axis=axis)
#    1425
#    1426     def _is_scalar_access(self, key: Tuple):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    2155
#    2156             # validate the location
# -> 2157             self._validate_integer(key, axis)
#    2158
#    2159             return self._get_loc(key, axis=axis)
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_integer(self, key, axis)
#    2086         len_axis = len(self.obj._get_axis(axis))
#    2087         if key >= len_axis or key < -len_axis:
# -> 2088             raise IndexError("single positional indexer is out-of-bounds")
#    2089
#    2090     def _getitem_tuple(self, tup):
#
# IndexError: single positional indexer is out-of-bounds
